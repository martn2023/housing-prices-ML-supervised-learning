# %%
'''Now that the data is prepared, import prepared data and TRAIN 3 models on it
'''

'''
Also known as EDA in data science, this is just a read-only activity to look at the data before writing improvements
'''

import os
import pandas #required to convert into a DataFrame
PROJECT_FILE_PATH = os.path.join("datasets", "housing")

csv_path = os.path.join(PROJECT_FILE_PATH, "prepared_training80_features_only.csv")
training80_features_df = pandas.read_csv(csv_path) 
training80_features_df.head()

csv_path = os.path.join(PROJECT_FILE_PATH, "prepared_training80_labels_only.csv")
training80_labels_df = pandas.read_csv(csv_path) 
training80_labels_df.head()
# Out:
#    median_house_value
# 0             72100.0
# 1            279600.0
# 2             82700.0
# 3            112500.0
# 4            238300.0

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(training80_features_df, training80_labels_df) #Again, features = contributing factors and labels = actual prices
# Out:
# LinearRegression()

# %%
#Special section to re-use Pipeline from Notebook 4
import joblib
pipeline_path = os.path.join(PROJECT_FILE_PATH, "full_pipeline_from_notebook4.pkl")

'''the below class is admittedly a repeat of code in Notebook4, but I would rather be guilty of repeating code this 1 time than
1. overcomplicate the process for such a small beginner project modularizing the code in a new and separate file
2. hide from a casual reader what the computer is doing
'''
from sklearn.base import BaseEstimator, TransformerMixin
class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room=True):  # Initialize with a hyperparameter
        self.add_bedrooms_per_room = add_bedrooms_per_room

    def fit(self, X, y=None):
        return self  # This transformer doesn't need to learn anything from the data, so we just return self

    def transform(self, X, y=None):
        rooms_per_household = X[:, rooms_index] / X[:, households_index]
        population_per_household = X[:, population_index] / X[:, households_index]
        if self.add_bedrooms_per_room:
            bedrooms_per_room = X[:, bedrooms_index] / X[:, rooms_index]
            return numpy.c_[X, rooms_per_household, population_per_household, bedrooms_per_room]
        else:
            return numpy.c_[X, rooms_per_household, population_per_household]

full_pipeline_from_notebook4 = joblib.load(pipeline_path)

# %%
'''since this is a linear regression, think of it as Price=a×A+b×B+c×C+Intercept where
1. lowercase a, b, c and INTERCEPT are the discovered/calculated coeffiencts
2. uppercase A B and C are the inputs coming from features such as household income or bedrooms per room

'''

some_data = training80_features_df.iloc[:3]
some_labels = training80_labels_df.iloc[:5]
some_data_prepared = full_pipeline_from_notebook4.transform(some_data)

print("Predictions:", lin_reg.predict(some_data_prepared)) # predicted housing prices for the first 5 rows of data, so want to dive into the math
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[12], line 9
#       7 some_data = training80_features_df.iloc[:3]
#       8 some_labels = training80_labels_df.iloc[:5]
# ----> 9 some_data_prepared = full_pipeline_from_notebook4.transform(some_data)
#      11 print("Predictions:", lin_reg.predict(some_data_prepared)) # predicted housing prices for the first 5 rows of data, so want to dive into the math
#
# File G:\My Drive\Education\BootCamp\housing-price-ML\venv\lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
# ...
