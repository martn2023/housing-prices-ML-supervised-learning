# %%
'''
Also known as EDA in data science, this is just a read-only activity to look at the data before writing improvements
'''

import os
import pandas #required to convert into a DataFrame

PROJECT_FILE_PATH = os.path.join("datasets", "housing")
csv_path = os.path.join(PROJECT_FILE_PATH, "stratified_training_80.csv")
eda_dataframe = pandas.read_csv(csv_path)

eda_dataframe.describe() #this matches readout in notebook #2
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16512.000000  16512.000000        16512.000000  16512.000000
# mean    -119.575635     35.639314           28.653404   2622.539789
# std        2.001828      2.137963           12.574819   2138.417080
# min     -124.350000     32.540000            1.000000      6.000000
# 25%     -121.800000     33.940000           18.000000   1443.000000
# 50%     -118.510000     34.260000           29.000000   2119.000000
# 75%     -118.010000     37.720000           37.000000   3141.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    16354.000000  16512.000000  16512.000000   16512.000000
# mean       534.914639   1419.687379    497.011810       3.875884
# std        412.665649   1115.663036    375.696156       1.904931
# min          2.000000      3.000000      2.000000       0.499900
# ...
